# %% [markdown]
# # Battle of Neighborhoods:Explore the Similarity of Given Metropolitan Cities
# ### Author:x.l.dang@Beijing,China. Feedback Email:xldang2020@gmail.com
#
# ## Table of contents
#
# * [Chapter 1. Battle understanding](#ch1)
# * [Chapter 2. Data Requirements](#ch2)
# * [Chapter 3. Data collection](#ch3)
#     * [3.1 import python dependency packages](#ch3.1)
#     * [3.2 Geography information of chosen metropolitan cities](#ch3.2)
#     * [3.3 Venue information of chosen metropolitan cities](#ch3.3)
# * [Chapter 4. Methodology](#ch4)
#     * [4.1 Load dataset](#ch4.1)
#     * [4.2 Modeling](#ch4.2)
#     * [4.3 Evaluation](#ch4.3)
# * [Chapter 5. Results](#ch5)
# * [Chapter 6. Discussion](#ch6)
# * [Chapter 7. Conclusion](#ch7)

# %% [markdown]
# # Chapter 1. Battle understanding<a name="ch1"></a>
#
# In this assignment, I explored New York City ,Toronto and other cities with their respective segmented and clustered neighborhoods. One interesting idea I explored is comparing the neighborhoods of the two cities and determine how similar or dissimilar they are. For example, is New York City more like Toronto or Paris or some other multicultural city?

# %% [markdown]
# # Chapter 2. Data Requirements<a name="ch2"></a>

# %% [markdown]
# For given metropolitan cities,I will explore the similarity of them from the perspective of venue distribution.The venues of a city are like human capillaries. Each venue is a small feature of the city. Together, these features can reflect a certain aspect of the city.
#
# <img src = "fig1 city venues.png" width = 500>
#
# <h1 align=center><font size = 3><em>Fig.1</em> City capillaries</font></h1>
#
# As shown in **Fig.1**, for a city, I need to collect its neighborhood(or district) data and the Venue data of each neighborhood.

# %% [markdown]
# # Chapter 3. Data collection<a name="ch3"></a>

# %% [markdown]
# In order to obtain the target data, I executed the following path:
#
# - Crawling wiki pages or other pages containing city district information
# - Perform data cleaning on crawled webpages
# - Obtain (Latitude,Longitude) infromation for each neighborhood/district using python toolkit <geopy.geocoders.Nominatim>
# - Extracting venue information for each (Latitude,Longitude) using Python API < FourSquare >
# - Each city corresponds to a pandas.DataFrame that stores target data.

# %% [markdown]
# ## 3.1 import python dependency packages<a name="ch3.1"></a>

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
#!pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
#! pip install folium==0.5.0
#import folium # plotting library
import seaborn as sns
import matplotlib.pyplot as plt

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## 3.2 Geography information of chosen metropolitan cities<a name="ch3.2"></a>
#
# Without any prejudice, I chose Shanghai, London, New York City, Frankfurt, and Toronto from five countries respectively: China, the United Kingdom, the United States, Germany, and Canada.
#
# - Shanghai,China
# - London, the United Kingdom
# - New York City, the United States
# - Frankfurt, Germany
# - Toronto,Canada

# %% [markdown]
# ### 3.2.1 A tiny case
#
# **Obtain the (Latitude,Longitude) infromation of location<E1,Head district,London>**

# %%
# for give postal_code and district ,return latitude and longitude.
postal_code,district='E1','Head district'
address ='{},{},London'.format(postal_code,district)
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude,'Success!')
# Out:
# 51.57607015 -0.08524000965140796 Success!

# %% [markdown]
# **Obtain the venue infromation of location (latitude, longitude).**

# %%
CLIENT_ID = 'QYHRIW4L1Y5WF2MAPABDG5WNS4CVTPBPM5GJ35W5R02SLMB2' # your Foursquare ID
CLIENT_SECRET = 'SAKZYG1K2PN1Z0V1VXFZZYHQF33DAZBNOTALAHYY0UWPYSL0' # your Foursquare Secret
VERSION = '20180604'
radius=500
LIMIT = 30
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude, 
            longitude, 
            radius, 
            LIMIT)
results = requests.get(url).json()["response"]['groups'][0]['items']
results[0]['venue'] # take a look
# Out:
# {'id': '550c6ef4498e5f9032d1f02b',
#  'name': 'New River Studios',
#  'location': {'address': '199 Eade Rd',
#   'lat': 51.57484776395148,
#   'lng': -0.08798988683904155,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 51.57484776395148,
#     'lng': -0.08798988683904155}],
#   'distance': 233,
#   'postalCode': 'N4 1DN',
#   'cc': 'GB',
#   'city': 'London',
#   'state': 'Greater London',
#   'country': 'United Kingdom',
#   'formattedAddress': ['199 Eade Rd',
#    'London',
#    'Greater London',
#    'N4 1DN',
#    'United Kingdom']},
#  'categories': [{'id': '4bf58dd8d48988d1f2931735',
#    'name': 'Performing Arts Venue',
#    'pluralName': 'Performing Arts Venues',
#    'shortName': 'Performing Arts',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#     'suffix': '.png'},
#    'primary': True}],
#  'photos': {'count': 0, 'groups': []}}

# %% [markdown]
# ### 3.2.2 Help functions

# %%
# generate_location_by_Postal Code
def gen_location_by_post(post_lis,district_lis,city=''):
    ans_pd=pd.DataFrame(columns=['Postal Code','Latitude','Longitude'])
    for post,district in zip(post_lis,district_lis):
        #print(post,district)
        address ='{},{},{}'.format(post,district,city)
        try:
            geolocator = Nominatim(user_agent="foursquare_agent")
            location = geolocator.geocode(address)
            latitude = location.latitude
            longitude = location.longitude
            print(post,district,latitude, longitude)
            ans_pd=ans_pd.append({'Postal Code':post,
                                  'Latitude':latitude,
                                 'Longitude':longitude},ignore_index=True)
        except:pass
    return ans_pd

# %%
# generate_location_by_district_name
def gen_location_by_district(district_lis,city=''):
    ans_pd=pd.DataFrame(columns=['District','Latitude','Longitude'])
    for district in district_lis:
        #print(district)
        address ='{},{}'.format(district,city)
        try:
            geolocator = Nominatim(user_agent="foursquare_agent")
            location = geolocator.geocode(address)
            latitude = location.latitude
            longitude = location.longitude
            print(district,latitude, longitude)
            ans_pd=ans_pd.append({'District':district,
                                  'Latitude':latitude,
                                 'Longitude':longitude},ignore_index=True)
        except:pass
    return ans_pd

# %%
# get Nearby Venues for a certain location(latitudes, longitudes)
def getNearbyVenues(names, latitudes, longitudes,radius,LIMIT):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['District', 
                  'District Latitude', 
                  'District Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### 3.2.3 Preparing London geography dataset
# https://en.wikipedia.org/wiki/London_postal_district
#
# **Store the target data in a .csv file by crawling the above URL**

# %%
London_POST=pd.read_csv('LONDON_POST.csv')
London_POST.head()
# Out:
#   Postal Code       District
# 0          E1  Head district
# 1          E2  Bethnal Green
# 2          E3           Bow
# 3          E4     Chingford
# 4          E5       Clapton

# %%
Location_with_post=gen_location_by_post(London_POST['Postal Code'].values,London_POST['District'].values,'London')
# Out:
# E1 Head district 51.57607015 -0.08524000965140796
# E2 Bethnal Green 51.5272449 -0.054752
# E3 Bow  51.529605 -0.0140886
# SE17 Walworth  51.4893842 -0.0961964
# SE18 Woolwich  51.4740285 0.0398315
# SE19 Norwood  51.4244214 -0.0919694
# SE20 Anerley  51.4123291 -0.057738
# SE21 Dulwich  51.4304081 -0.0799247
# SE22 East Dulwich 51.4416761 -0.0653871
# SE23 Forest Hill 51.5156177 -0.0919983
# SE24 Herne Hill 51.4416752 -0.105838
# SE25 South Norwood 51.3931581 -0.0669774
# SE26 Sydenham  51.434745 -0.0623883
# SE27 West Norwood 51.4278012 -0.1042691
# SW1 Head district 51.57607015 -0.08524000965140796
# SW2 Brixton  51.4626818 -0.1147325
# SW3 Chelsea  51.49189143665097 -0.16640948467359915
# SW4 Clapham  51.4622924 -0.1388561
# SW5 Earls Court 51.4916123 -0.193903
# SW6 Fulham  51.48317875172319 -0.19955152488785663
# SW7 South Kensington 51.4940494 -0.1730439
# SW8 South Lambeth 51.5013012 -0.117287
# SW9 Stockwell  51.47676436917647 -0.11093317358145417
# SW10 West Brompton 51.4869765 -0.1951854
# SW12 Balham  51.4428285 -0.1514426
# SW13 Barnes  51.466783 -0.2411817
# SW14 Mortlake  51.4680686 -0.2669404
# SW15 Putney  51.4609339 -0.2153478
# SW16 Streatham  51.4259609 -0.1313131
# SW17 Tooting  51.4198634 -0.1614119
# SW18 Wandsworth  51.4469934348484 -0.17809128186418324
# SW19 Wimbledon  51.4209162 -0.2059098
# SW20 West Wimbledon 51.4129332 -0.2176577
# W1 Head district 51.57607015 -0.08524000965140796
# W2 Head district 51.57607015 -0.08524000965140796
# W3 Acton  51.5081402 -0.2732607
# W4 Chiswick  51.4811465 -0.2681753
# W5 Ealing  51.509446501112784 -0.30207676374776954
# W6 Hammersmith  51.49829947921515 -0.2253548353430013
# W7 Hanwell  51.5117871 -0.3386659
# W8 Kensington  51.50450671394932 -0.19557021163117017
# W9 Maida Hill 51.5240989 -0.194717
# W10 North Kensington 51.5196647 -0.2106959
# W11 Notting Hill 51.511009 -0.2055004
# W12 Shepherds Bush 51.5043576 -0.2183251
# W13 West Ealing 51.5135091 -0.3207704
# W14 West Kensington 51.4906622 -0.205916

# %%
Location_with_post.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0          E1  51.576070  -0.085240
# 1          E2  51.527245  -0.054752
# 2          E3  51.529605  -0.014089
# 3          E4  51.632534   0.009471
# 4          E5  51.561653  -0.056807

# %% [markdown]
# **Merge the Location_with_post and the London_POST**

# %%
geo_merged_London=pd.merge(London_POST,Location_with_post,on='Postal Code')

# %%
geo_merged_London.head()
# Out:
#   Postal Code       District   Latitude  Longitude
# 0          E1  Head district  51.576070  -0.085240
# 1          E2  Bethnal Green  51.527245  -0.054752
# 2          E3           Bow   51.529605  -0.014089
# 3          E4     Chingford   51.632534   0.009471
# 4          E5       Clapton   51.561653  -0.056807

# %% [markdown]
# **Store data locally**

# %%
geo_merged_London.to_csv('geo_merged_London.csv',index=None)

# %% [markdown]
# ### 3.2.4 Preparing New York geography dataset
# https://en.wikipedia.org/wiki/Neighborhoods_in_New_York_City
#
# **Store the target data in a .html file by crawling the above URL**

# %%
# read NewYork_district
NewYork_district=pd.read_html('NewYork.html')
NewYork_district=NewYork_district[0]
NewYork_district=NewYork_district.drop(['Areakm2','Pop.Census2010','Pop./km2'],axis=1)
NewYork_district.columns=['Borough','Neighbourhoods']
NewYork_district.head()
# Out:
#       Borough                                     Neighbourhoods
# 0  Bronx CB 1                   Melrose, Mott Haven, Port Morris
# 1  Bronx CB 2                              Hunts Point, Longwood
# 2  Bronx CB 3  Claremont, Concourse Village, Crotona Park, Mo...
# 3  Bronx CB 4                              Concourse, Highbridge
# 4  Bronx CB 5  Fordham, Morris Heights, Mount Hope, Universit...

# %%
# One row split into multipy rows
NewYork_district_expandrows=NewYork_district.drop('Neighbourhoods', axis=1).join(NewYork_district['Neighbourhoods'].str.split(',', expand=True).stack().reset_index(level=1, drop=True).rename('District'))
NewYork_district_expandrows=NewYork_district_expandrows.dropna()
NewYork_district_expandrows.reset_index(drop=True,inplace=True)
NewYork_district_expandrows=NewYork_district_expandrows.iloc[::2]
NewYork_district_expandrows.reset_index(drop=True,inplace=True) # again
NewYork_district_expandrows.head()
# Out:
#       Borough            District
# 0  Bronx CB 1             Melrose
# 1  Bronx CB 1         Port Morris
# 2  Bronx CB 2            Longwood
# 3  Bronx CB 3   Concourse Village
# 4  Bronx CB 3          Morrisania

# %%
print("Before drop_duplicates,NewYork_district_expandrows.shape is: ",NewYork_district_expandrows.shape)
NewYork_district_expandrows=NewYork_district_expandrows.drop_duplicates(subset=['District'], keep='first')
print("After drop_duplicates,NewYork_district_expandrows.shape is: ",NewYork_district_expandrows.shape)
# Out:
# Before drop_duplicates,NewYork_district_expandrows.shape is:  (165, 2)
# After drop_duplicates,NewYork_district_expandrows.shape is:  (163, 2)

# %%
Location_with_district=gen_location_by_district(NewYork_district_expandrows['District'].values,'New York')
# Out:
# Melrose 40.8256703 -73.9152416
#  Port Morris 40.8015147 -73.9095811
#  Longwood 42.9531152 -78.3694646
#  Concourse Village 40.823868149999996 -73.92118091218828
#  Morrisania 40.8292672 -73.9065253
#  Highbridge 40.84591775 -73.92984478686536
#  Morris Heights 40.8498223 -73.919859
#  University Heights 40.8618406 -73.9135154
#  Belmont 42.2231241 -78.0344506
#  West Farms 40.8398226 -73.8776356
#  Norwood 44.75161 -74.994392
# Fieldston 40.8944444 -73.9033333
#  Kingsbridge Heights 40.8725702 -73.9026619
#  Riverdale 40.90056 -73.90639
#  Van Cortlandt Village 41.2486935 -73.90858593483966
#  Bruckner 40.8266667 -73.8286111
#  Clason Point 40.8147164 -73.8599648
#  Parkchester 40.8332047 -73.8609723
#  Unionport 40.8273229 -73.8501349
#  Co-op City 40.8738889 -73.8294444
#  Pelham Bay 40.8662112 -73.7895774
#  Throgs Neck 40.8226008 -73.8195784
# Allerton 40.8654299 -73.8673652
#  Indian Village 42.9439553 -76.1624253
#  Morris Park 40.8545235 -73.8602968
#  Pelham Parkway 40.8588576 -73.8554627
# Baychester 40.8612222 -73.8412865
#  Glendale 40.7014917 -73.8868028
#  Middle Village 40.718215650000005 -73.87867154730415
#  Ridgewood 40.7080556 -73.9141667
#  Rego Park 40.72286495 -73.86210197975404
#  Beechhurst 40.7914903 -73.8045781
#  Flushing 40.7654301 -73.8174291
#  Malba 40.7906569 -73.8268009
#  Whitestone 40.7945457 -73.8184674
# Briarwood 40.7092563 -73.8201394
#  Holliswood 42.7429008 -73.7728673
#  Pomonok Houses 40.7332433 -73.81277820488998
# Kew Gardens 40.7139415 -73.830742
#  Richmond Hill 43.880078 -79.439392
# Howard Beach 40.6578815 -73.8362459
#  Tudor Village 51.6814067 -0.3822256
#  Bayside 40.7684351 -73.7770774
#  East Flushing 40.757536599999995 -73.78430452865169
#  Little Neck 40.7745338 -73.7412564
#  Hollis 40.7134361 -73.7670772
#  St. Albans 40.6984364 -73.7606881
#  Springfield Gardens 40.678159 -73.746521
#  Brookville 40.8131553 -73.5673482
#  Floral Park 40.7246999 -73.7048024
#  Laurelton 40.6667703 -73.7515212
#  New Hyde Park 40.7352157 -73.6883239
#  Rosedale 40.6620479 -73.7354097
#  Bayswater 40.6102778 -73.7672222
#  Breezy Point 40.5562952 -73.9267466193535
#  Far Rockaway 40.6053825 -73.7551326
#  Rockaway Park 40.5805104 -73.8361535
# Arlington 41.694069 -73.88636347613317
#  Clifton 40.6201041 -74.0770857
#  Elm Park 40.6314925 -74.1487544
#  Graniteville 40.6248259 -74.1484765
#  Livingston 42.7360902 -77.7781416
#  Port Ivory 40.6409366 -74.1801442
#  Randall Manor 40.6441993 -74.10457640394483
#  St. George 40.6439626 -74.0734416
#  Silver Lake 42.601463 -75.3323938
#  West Brighton 40.5780247 -73.97492614655985
# Arrochar 40.5984379 -74.0726412
#  Bulls Head 40.6070484 -74.1620879
#  Dongan Hills 40.588438 -74.0962528
#  Emerson Hill 40.6085851 -74.0945642
#  Grasmere 40.6042711 -74.087086
#  New Dorp 40.5739938 -74.1159755
#  Oakwood 43.6827255 -79.4380548
#  Old Town 40.5967018 -74.08732595968985
#  Todt Hill 40.6010083 -74.1150363
# Annadale 40.5445496 -74.1765324
#  Bay Terrace 40.5552778 -74.1341667
#  Eltingville 40.5453831 -74.1656988
#  Greenridge 40.5612236 -74.1698852
#  Pleasant Plains 40.5239944 -74.2156999
#  Richmond Valley 40.5201055 -74.2293113
#  Tottenville 40.5112167 -74.2493117

# %%
Location_with_district.head()
# Out:
#              District   Latitude  Longitude
# 0             Melrose  40.825670 -73.915242
# 1         Port Morris  40.801515 -73.909581
# 2            Longwood  42.953115 -78.369465
# 3   Concourse Village  40.823868 -73.921181
# 4          Morrisania  40.829267 -73.906525

# %%
geo_merged_NewYork=pd.merge(NewYork_district_expandrows,Location_with_district,on='District')

# %%
geo_merged_NewYork.head()
# Out:
#       Borough            District   Latitude  Longitude
# 0  Bronx CB 1             Melrose  40.825670 -73.915242
# 1  Bronx CB 1         Port Morris  40.801515 -73.909581
# 2  Bronx CB 2            Longwood  42.953115 -78.369465
# 3  Bronx CB 3   Concourse Village  40.823868 -73.921181
# 4  Bronx CB 3          Morrisania  40.829267 -73.906525

# %%
geo_merged_NewYork.to_csv('geo_merged_NewYork.csv',index=None)

# %% [markdown]
# ### 3.2.5 Preparing Frankfurt geography dataset
# https://en.wikipedia.org/wiki/List_of_Ortsbezirke_of_Frankfurt_am_Main
#
# **Store the target data in a .html file by crawling the above URL**

# %%
Frankfurt=pd.read_html("Frankfurt.html")
Frankfurt_district=Frankfurt[0].drop(['No.','Population','Area(km²)','Population density(Population/km²)'],axis=1)
Frankfurt_district.columns=['Borough','District']
Frankfurt_district
# Out:
#              Borough                                           District
# 0       Innenstadt I  Altstadt, Bahnhofsviertel, Gallus, Gutleutvier...
# 1      Innenstadt II              Bockenheim, Westend-Nord, Westend-Süd
# 2     Innenstadt III                          Nordend-Ost, Nordend-West
# 3    Bornheim/Ostend                                   Ostend, Bornheim
# 4                Süd  Flughafen, Niederrad, Oberrad, Sachsenhausen-S...
# 5               West  Griesheim, Höchst, Nied, Schwanheim, Sindlinge...
# 6         Mitte-West                       Rödelheim, Praunheim, Hausen
# 7          Nord-West                           Niederursel, Heddernheim
# 8         Mitte-Nord                   Eschersheim, Ginnheim, Dornbusch
# 9           Nord-Ost  Eckenheim, Preungesheim, Berkersheim, Frankfur...
# 10               Ost                   Seckbach, Riederwald, Fechenheim
# 11  Kalbach-Riedberg                                   Kalbach-Riedberg
# 12  Nieder-Erlenbach                                   Nieder-Erlenbach
# 13           Harheim                                            Harheim
# 14   Nieder-Eschbach                                    Nieder-Eschbach
# 15    Bergen-Enkheim                                     Bergen-Enkheim

# %%
# One row split into multipy rows
Frankfurt_district_expandrows=Frankfurt_district.drop('District', axis=1).join(Frankfurt_district['District'].str.split(',', expand=True).stack().reset_index(level=1, drop=True).rename('District'))
#Frankfurt_district_expandrows=Frankfurt_district_expandrows.dropna()
Frankfurt_district_expandrows.reset_index(drop=True,inplace=True)
Frankfurt_district_expandrows.head()
# Out:
#         Borough          District
# 0  Innenstadt I          Altstadt
# 1  Innenstadt I   Bahnhofsviertel
# 2  Innenstadt I            Gallus
# 3  Innenstadt I    Gutleutviertel
# 4  Innenstadt I        Innenstadt

# %%
Location_Frankfurt_district=gen_location_by_district(Frankfurt_district_expandrows['District'].values,'Frankfurt')
# Out:
# Altstadt 50.1104436 8.6823506
#  Bahnhofsviertel 50.1084107 8.6681512
#  Gallus 50.1038405 8.6431009
#  Gutleutviertel 50.1017076 8.6605407
#  Innenstadt 50.1145581 8.6835914
# Bockenheim 50.1233115 8.6460563
#  Westend-Nord 50.1263563 8.6679209
#  Westend-Süd 50.1152448 8.6622696
# Nordend-Ost 50.1249197 8.6923167
#  Nordend-West 50.1249136 8.67795
# Ostend 50.1123728 8.6999671
#  Bornheim 50.1297313 8.7106117
# Flughafen 50.04303025 8.567283919206004
#  Niederrad 50.0882911 8.6427072
#  Oberrad 50.100008 8.7231359
#  Sachsenhausen-Süd 50.0707248 8.685449728161462
#  Sachsenhausen-Nord 50.0978128 8.67336208063444
# Griesheim 50.0914289 8.6078631
#  Höchst 50.0995118 8.5452956
#  Nied 50.1007301 8.5722132
#  Schwanheim 50.0853006 8.5836267
#  Sindlingen 50.0798368 8.5179804
#  Sossenheim 50.1201215 8.5666158
#  Unterliederbach 50.1104064 8.5322471
#  Zeilsheim 50.0955649 8.4947834
# Rödelheim 50.1249843 8.6125536
#  Praunheim 50.1507958 8.6215134
#  Hausen 50.1320084 8.6243618
# Niederursel 50.1690572 8.6188761
#  Heddernheim 50.159627 8.6466155
# Eschersheim 50.1582027 8.6562116
#  Ginnheim 50.143081 8.6498558
#  Dornbusch 50.1390457 8.6752715
# Eckenheim 50.1517101 8.6797459
#  Preungesheim 50.1565402 8.6878166
#  Berkersheim 50.1732889 8.6973119
#  Frankfurter Berg 50.1680209 8.6756884
#  Bonames 50.1813474 8.6633305
# Seckbach 50.1434285 8.7258861
#  Riederwald 50.1288376 8.7331285
#  Fechenheim 50.123015 8.7693856
# Kalbach-Riedberg 50.186279299999995 8.639054519087743
# Nieder-Erlenbach 50.2026088 8.7119602
# Harheim 50.182287 8.6929716
# Nieder-Eschbach 50.2017328 8.666710664514689
# Bergen-Enkheim 50.15801465 8.762038791958947

# %%
Location_Frankfurt_district.head()
# Out:
#            District   Latitude  Longitude
# 0          Altstadt  50.110444   8.682351
# 1   Bahnhofsviertel  50.108411   8.668151
# 2            Gallus  50.103840   8.643101
# 3    Gutleutviertel  50.101708   8.660541
# 4        Innenstadt  50.114558   8.683591

# %%
geo_merged_Frankfurt=pd.merge(Location_Frankfurt_district,Frankfurt_district_expandrows,on='District')

# %%
geo_merged_Frankfurt.head()
# Out:
#            District   Latitude  Longitude       Borough
# 0          Altstadt  50.110444   8.682351  Innenstadt I
# 1   Bahnhofsviertel  50.108411   8.668151  Innenstadt I
# 2            Gallus  50.103840   8.643101  Innenstadt I
# 3    Gutleutviertel  50.101708   8.660541  Innenstadt I
# 4        Innenstadt  50.114558   8.683591  Innenstadt I

# %%
geo_merged_Frankfurt.to_csv("geo_merged_Frankfurt.csv",index=None)

# %% [markdown]
# ### 3.2.6 Preparing Shanghai geography dataset
# https://baike.baidu.com/item/%E4%B8%8A%E6%B5%B7%E8%A1%8C%E6%94%BF%E5%8C%BA%E5%88%92/7426389?fr=aladdin
#
# Store the target data in a .html file by crawling the above URL

# %%
SH=pd.read_html("Shanghai.html")
SH=SH[0].drop([1,2,3,4,6],axis=1).dropna()
SH=SH.iloc[1:,:]
SH.reset_index(drop=True,inplace=True)
SH.columns=['Borough','District']
# one row into multi.
SH_expandrows=SH.drop('District', axis=1).join(SH['District'].str.split('、', expand=True).stack().reset_index(level=1, drop=True).rename('District'))

# %%
SH_expandrows
# Out:
#    Borough District
# 0      黄浦区     外滩街道
# 0      黄浦区     豫园街道
# 0      黄浦区    小东门街道
# 0      黄浦区    老西门街道
# 江浦路街道 29.817962 106.159272
# 控江路街道 31.2755949 121.5077941
# 长海路街道 37.0268611 121.9739008
# 五角场街道 31.3064494 121.5125653
# 四平路街道 36.0858558 120.3529756
# 定海路街道 37.1888783 119.9390674
# 新江湾城街道 31.3307804 121.5023484
# 延吉新村街道 29.3111989 117.2058923
# 古美街道 9.9313167 115.5221101
# 新虹街道 22.6927786 120.3510529
# 浦锦街道 31.2322758 121.4692071
# 江川路街道 31.0113391 121.4130041
# 吴淞街道 31.3745763 121.4895071
# 张庙街道 31.3385346 121.4372383
# 友谊路街道 43.8936877 87.51425225469008
# 真新街道 31.2462706 121.3556599
# 嘉定镇街道 31.3861987 121.2461028
# 新成路街道 31.3883629 121.2653418
# 花木街道 36.3991761 139.7594944
# 洋泾街道 31.241739350000003 121.54317680114835
# 塘桥街道 40.1840602 117.5932807
# 浦兴路街道 31.2687801 121.5839936
# 陆家嘴街道 31.24016825 121.49794463601899
# 周家渡街道 31.18714625 121.4892365
# 东明路街道 33.8786801 115.4537153
# 上钢新村街道 29.3111989 117.2058923
# 沪东新村街道 39.6349762 118.21683
# 金杨新村街道 29.3111989 117.2058923
# 南码头路街道 31.191186 121.5081099
# 潍坊新村街道 34.8011479 135.6328833
# 石化街道 30.7278708 121.3321733
# 岳阳街道 31.0182765 121.2313372
# 中山街道 31.0384758 121.24118
# 永丰街道 30.5659165 114.16954189233239
# 方松街道 31.046825400000003 121.20148303626398
# 广富林街道 31.051115 121.217627
# 九里亭街道 31.1434576 121.3065846
# 夏阳街道 31.1501939 121.120585
# 盈浦街道 31.1475268 121.1098573
# 香花桥街道 31.1731032 121.1180277
# 西渡街道 31.2322758 121.4692071
# 奉浦街道 30.492517 116.35097
# 金海街道 42.8300763 130.3734902
# 新村乡 31.8311419 121.3276315
# 横沙乡 31.3427721 121.8375283

# %%
Location_SH_district.head()
# Out:
#   District   Latitude   Longitude
# 0     外滩街道  29.887552  121.553385
# 1     豫园街道  31.227362  121.483061
# 2    小东门街道  31.221936  121.496580
# 3    老西门街道  31.217151  121.481602
# 4    打浦桥街道  31.205621  121.468717

# %%
geo_merged_SH=pd.merge(Location_SH_district,SH_expandrows,on='District')

# %%
geo_merged_SH.head()
# Out:
#   District   Latitude   Longitude Borough
# 0     外滩街道  29.887552  121.553385     黄浦区
# 1     豫园街道  31.227362  121.483061     黄浦区
# 2    小东门街道  31.221936  121.496580     黄浦区
# 3    老西门街道  31.217151  121.481602     黄浦区
# 4    打浦桥街道  31.205621  121.468717     黄浦区

# %%
geo_merged_SH.to_csv('ShangHai.csv',index=None)

# %% [markdown]
# ### 3.2.7 Preparing Toronto geography dataset
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# **Since Toronto's data has been obtained in the coursework, it can be used directly here.It store in local<geo_merged_Toronto.csv>**

# %% [markdown]
# ## 3.3  Venue information of chosen metropolitan cities<a name="ch3.3"></a>

# %% [markdown]
# ### 3.3.1 Read prepared geo. dataset

# %%
geo_merged_London=pd.read_csv('geo_merged_London.csv')
geo_merged_Torondo=pd.read_csv('geo_merged_Toronto.csv')
geo_merged_NewYork=pd.read_csv('geo_merged_NewYork.csv')
geo_merged_Frankfurt=pd.read_csv('geo_merged_Frankfurt.csv')
geo_merged_SH=pd.read_csv('ShangHai.csv')
print('geo_merged_London.shape is ',geo_merged_London.shape)
print('geo_merged_Torondo.shape is ',geo_merged_Torondo.shape)
print('geo_merged_NewYork.shape is ',geo_merged_NewYork.shape)
print('geo_merged_Frankfurt.shape is ',geo_merged_Frankfurt.shape)
print('geo_merged_SH.shape is ',geo_merged_SH.shape)
# Out:
# geo_merged_London.shape is  (110, 4)
# geo_merged_Torondo.shape is  (103, 4)
# geo_merged_NewYork.shape is  (151, 4)
# geo_merged_Frankfurt.shape is  (46, 4)
# geo_merged_SH.shape is  (108, 4)

# %% [markdown]
# ### 3.3.2 Generate district nearby Venues

# %%
CLIENT_ID = 'QYHRIW4L1Y5WF2MAPABDG5WNS4CVTPBPM5GJ35W5R02SLMB2' # your Foursquare ID
CLIENT_SECRET = 'SAKZYG1K2PN1Z0V1VXFZZYHQF33DAZBNOTALAHYY0UWPYSL0' # your Foursquare Secret
VERSION = '20180604'

# %%
toronto_venues = getNearbyVenues(names=geo_merged_Torondo['District'],
                                   latitudes=geo_merged_Torondo['Latitude'],
                                   longitudes=geo_merged_Torondo['Longitude'],
                                   radius=500,
                                   LIMIT=100
                                  )
SH_venues = getNearbyVenues(names=geo_merged_SH['District'],
                                   latitudes=geo_merged_SH['Latitude'],
                                   longitudes=geo_merged_SH['Longitude'],
                                   radius=500,
                                   LIMIT=100
                                  )
NewYork_venues = getNearbyVenues(names=geo_merged_NewYork['District'],
                                   latitudes=geo_merged_NewYork['Latitude'],
                                   longitudes=geo_merged_NewYork['Longitude'],
                                   radius=500,
                                   LIMIT=100
                                  )
London_venues = getNearbyVenues(names=geo_merged_London['District'],
                                   latitudes=geo_merged_London['Latitude'],
                                   longitudes=geo_merged_London['Longitude'],
                                   radius=500,
                                   LIMIT=100
                                  )
Frankfurt_venues = getNearbyVenues(names=geo_merged_Frankfurt['District'],
                                   latitudes=geo_merged_Frankfurt['Latitude'],
                                   longitudes=geo_merged_Frankfurt['Longitude'],
                                   radius=1000,
                                   LIMIT=100
                                  )

# %%
toronto_venues.to_csv('toronto_venues.csv',index=None)
SH_venues.to_csv('SH_venues.csv',index=None)
NewYork_venues.to_csv('NewYork_venues.csv',index=None)
London_venues.to_csv('London_venues.csv',index=None)
Frankfurt_venues.to_csv('Frankfurt_venues.csv',index=None)

# %% [markdown]
# ### 3.3.3 Venue dataset summary
# **Take a look at London_venues, it's shown that there $3429$ Venues are collected with total $282$ categories.**

# %%
London_venues
# Out:
#              District  District Latitude  District Longitude  \
# 0       Head district          51.576070           -0.085240
# 1       Head district          51.576070           -0.085240
# 2       Head district          51.576070           -0.085240
# 3       Head district          51.576070           -0.085240
# 4       Head district          51.576070           -0.085240
# ...               ...                ...                 ...
# 3424  West Kensington          51.490662           -0.205916
# 3425  West Kensington          51.490662           -0.205916
# 3426  West Kensington          51.490662           -0.205916
# 3427  West Kensington          51.490662           -0.205916
# 3428  West Kensington          51.490662           -0.205916
#
#                       Venue  Venue Latitude  Venue Longitude  \
# 0         New River Studios       51.574848        -0.087990
# 1        Florentina Fitness       51.576162        -0.089063
# 2        gurbet supermarket       51.577885        -0.082615
# 3        No.8 Seven Sisters       51.578388        -0.082060
# 4             Amhurst Hotel       51.574609        -0.079411
# ...                     ...             ...              ...
# 3424                  Tesco       51.492879        -0.201221
# 3425         Maurizio Barca       51.489406        -0.206283
# 3426         Domino's Pizza       51.493239        -0.208804
# 3427  Simply Rooms & Suites       51.494563        -0.207051
# 3428                   Nisa       51.490603        -0.211970
#
#              Venue Category
# 0     Performing Arts Venue
# 1                       Gym
# 2             Grocery Store
# 3                    Hostel
# 4                     Hotel
# ...                     ...
# 3424            Supermarket
# 3425     Italian Restaurant
# 3426            Pizza Place
# 3427                  Hotel
# 3428      Convenience Store
#
# [3429 rows x 7 columns]

# %%
cats=London_venues['Venue Category'].unique()

# %%
len(cats)
# Out:
# 282

# %% [markdown]
# # Chapter 4. Methodology<a name="ch4"></a>
#
# **In this section, I will calculate the frequency of each venue category in each city. Then the similarity distance of each city can be obtained.**

# %% [markdown]
# ## 4.1 Load dataset <a name="ch4.1"></a>

# %%
Toronto_venues=pd.read_csv('toronto_venues.csv')
SH_venues=pd.read_csv('SH_venues.csv')
NewYork_venues=pd.read_csv('NewYork_venues.csv')
London_venues=pd.read_csv('London_venues.csv')
Frankfurt_venues=pd.read_csv('Frankfurt_venues.csv')
print('Toronto_venues.shape is ',Toronto_venues.shape)
print('SH_venues.shape is ',SH_venues.shape)
print('NewYork_venues.shape is ',NewYork_venues.shape)
print('London_venues.shape is ',London_venues.shape)
print('Frankfurt_venues.shape is ',Frankfurt_venues.shape)
# Out:
# Toronto_venues.shape is  (2115, 7)
# SH_venues.shape is  (1128, 7)
# NewYork_venues.shape is  (4665, 7)
# London_venues.shape is  (3429, 7)
# Frankfurt_venues.shape is  (1768, 7)

# %% [markdown]
# ## 4.2 Modeling<a name="ch4.2"></a>
#
# **Calculate the frequency of each venue category in each city**
#
# - Gather all Categories among these five cities.

# %%
# All Categories among these five cities.
allCats=list(set(Toronto_venues['Venue Category'].values.tolist()+SH_venues['Venue Category'].values.tolist()+NewYork_venues['Venue Category'].values.tolist()+London_venues['Venue Category'].values.tolist()+Frankfurt_venues['Venue Category'].values.tolist()))
len(allCats)
# Out:
# 498

# %% [markdown]
# - Calculate frequency.

# %%
def gen_Freqency(cityName,allCats,dFrame):
    ansFrame=pd.DataFrame([[cityName]],columns=['City'])
    for cat in allCats:
        filterFrame=dFrame[dFrame['Venue Category']==cat]
        freq=filterFrame.shape[0]/dFrame.shape[0]
        ansFrame[cat]=freq
    return ansFrame

# %%
Toronto_Freq=gen_Freqency('Toronto',allCats,Toronto_venues)
# Take a look
Toronto_Freq
# Out:
#       City  Antique Shop  Cupcake Shop  Hotel Pool  Design Studio  Daycare  \
# 0  Toronto      0.001418      0.000946         0.0            0.0      0.0
#
#    Ramen Restaurant  Cultural Center  Fish Market  Udon Restaurant  ...  \
# 0           0.00331              0.0     0.002364              0.0  ...
#
#    Boat or Ferry  Public Art  Tailor Shop  Paper / Office Supplies Store  \
# 0       0.000473         0.0     0.002364                            0.0
#
#    Spanish Restaurant  History Museum  Gymnastics Gym  Dive Bar  \
# 0                 0.0        0.001418             0.0       0.0
#
#    Trattoria/Osteria  College Arts Building
# 0                0.0               0.000473
#
# [1 rows x 499 columns]

# %%
Shanghai_Freq=gen_Freqency('Shanghai',allCats,SH_venues)
London_Freq=gen_Freqency('London',allCats,London_venues)
NewYork_Freq=gen_Freqency('NewYork',allCats,NewYork_venues)
Frankfurt_Freq=gen_Freqency('Frankfurt',allCats,Frankfurt_venues)

# %% [markdown]
# - Merge values.

# %%
all_Freq=pd.concat([Shanghai_Freq,London_Freq,NewYork_Freq,Frankfurt_Freq,Toronto_Freq])
all_Freq.index=all_Freq['City'].values
all_Freq=all_Freq.drop(['City'],axis=1)
all_Freq
# Out:
#            Antique Shop  Cupcake Shop  Hotel Pool  Design Studio   Daycare  \
# Shanghai       0.000000      0.000000    0.000000       0.000000  0.000000
# London         0.001167      0.002625    0.000000       0.000583  0.000000
# NewYork        0.000429      0.000643    0.000214       0.000000  0.000214
# Frankfurt      0.000000      0.000000    0.000000       0.000000  0.000000
# Toronto        0.001418      0.000946    0.000000       0.000000  0.000000
#
#            Ramen Restaurant  Cultural Center  Fish Market  Udon Restaurant  \
# Shanghai           0.005319         0.000000     0.000000         0.000000
# London             0.001750         0.000000     0.000875         0.000292
# NewYork            0.001929         0.000429     0.000643         0.000214
# Frankfurt          0.001697         0.000000     0.000000         0.000000
# Toronto            0.003310         0.000000     0.002364         0.000000
#
#            Kids Store  ...  Boat or Ferry  Public Art  Tailor Shop  \
# Shanghai     0.000000  ...       0.000887    0.000000     0.000000
# London       0.001167  ...       0.000292    0.000000     0.000000
# NewYork      0.002358  ...       0.001501    0.000429     0.000214
# Frankfurt    0.000566  ...       0.000000    0.000000     0.000000
# Toronto      0.000473  ...       0.000473    0.000000     0.002364
#
#            Paper / Office Supplies Store  Spanish Restaurant  History Museum  \
# Shanghai                        0.000000            0.001773        0.007979
# London                          0.000000            0.001458        0.002333
# NewYork                         0.000643            0.005573        0.001929
# Frankfurt                       0.000566            0.005656        0.003394
# Toronto                         0.000000            0.000000        0.001418
#
#            Gymnastics Gym  Dive Bar  Trattoria/Osteria  College Arts Building
# Shanghai         0.000000  0.000000           0.000000               0.000000
# London           0.000000  0.000000           0.000000               0.000000
# NewYork          0.000214  0.001286           0.000000               0.000214
# Frankfurt        0.001131  0.000000           0.002828               0.000000
# Toronto          0.000000  0.000000           0.000000               0.000473
#
# [5 rows x 498 columns]

# %% [markdown]
# ## 4.3 Evaluation<a name="ch4.3"></a>
#
# **Compute pairwise correlation of cities according to venue category frequency values.**

# %%
city_corr=all_Freq.T.corr()
city_corr
# Out:
#            Shanghai    London   NewYork  Frankfurt   Toronto
# Shanghai   1.000000  0.636168  0.558532   0.480385  0.729699
# London     0.636168  1.000000  0.637411   0.611683  0.791106
# NewYork    0.558532  0.637411  1.000000   0.544476  0.727447
# Frankfurt  0.480385  0.611683  0.544476   1.000000  0.574084
# Toronto    0.729699  0.791106  0.727447   0.574084  1.000000

# %% [markdown]
# **Plotting a heatmap correlation matrix**

# %%
sns.heatmap(city_corr,annot=True, fmt=".3f",cmap="YlGnBu")

# %% [markdown]
# # Chapter 5. Results<a name="ch5"></a>
#
# According to *city_corr*,we can find that the similarity of the 5 cities in descending order is:
#     1. Toronto-London: 0.791 （Correlation coefficient）
#     2. Toronto-Shanghai:0.730
#     3. Toronto-NewYork :0.727
#     4. NewYork-London: 0.637
#     5. London-Shanghai:0.636
#     6. Frankfurt-London:0.612
#     7. Toronto-Frankfurt:0.574
#     8. NewYork-Shanghai :0.559
#     9. Frankfurt-NewYork: 0.544
#     10. Frankfurt-Shanghai: 0.480

# %% [markdown]
# # Chapter 6. Discussion <a name="ch6"></a>
#
# Let's take a look at Toronto-London venue frequency dataset to explore something interesting.

# %%
Toronto_Freq_dis=Toronto_Freq.drop(['City'],axis=1).T
Toronto_Freq_dis.columns=['coefficient']
Toronto_Freq_dis.sort_values(by=['coefficient'],ascending=False).head(10)
# Out:
#                      coefficient
# Coffee Shop             0.085579
# Café                    0.043972
# Restaurant              0.031678
# Park                    0.025059
# Bakery                  0.022222
# Pizza Place             0.021749
# Italian Restaurant      0.021277
# Sandwich Place          0.020331
# Japanese Restaurant     0.019858
# Hotel                   0.018440

# %%
London_Freq_dis=London_Freq.drop(['City'],axis=1).T
London_Freq_dis.columns=['coefficient']
London_Freq_dis.sort_values(by=['coefficient'],ascending=False).head(10)
# Out:
#                       coefficient
# Pub                      0.066492
# Coffee Shop              0.063575
# Café                     0.054826
# Grocery Store            0.040537
# Hotel                    0.031788
# Italian Restaurant       0.024205
# Pizza Place              0.023914
# Gym / Fitness Center     0.022747
# Sandwich Place           0.021289
# Bakery                   0.020122

# %% [markdown]
# **Now, we can intuitively see that the most frequent venues in these two cities are highly similar. This reflects the high similarity in the working environment, lifestyle and entertainment styles of the two cities**

# %% [markdown]
# # Chapter 7. Conclusion<a name="ch7"></a>
#
#
# For given metropolitan cities,I explored the similarity of them from the perspective of venue distribution. After web crawling, cleaning, feature acquisition and data integration, I obtain the location distribution and category of the venue in each district of a city. I calculated the frequency of the venue category in different cities and generated a correlation matrix between cities.
#
#
# I prefer to think that the higher correlation coefficient of the venue occur frequency  represents the higher similarity in the working environment, lifestyle and entertainment styles of the two cities.Therefore,for these five cities I explored in this assignment, **Toronto，Canada and London，the United Kingdom are the most similar, Frankfurt,Germany and Shanghai,China are the least similar.** For other cities in the world,I think my assignment can still be used as an effective solution for calculating city similarity.
