# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


#!pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


#! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting geopy
#   Downloading geopy-2.1.0-py3-none-any.whl (112 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.1.0
# Requirement already satisfied: folium==0.5.0 in c:\programdata\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: branca in c:\programdata\anaconda3\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from folium==0.5.0) (2.11.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium==0.5.0) (2.22.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from folium==0.5.0) (1.14.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium==0.5.0) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2.8)
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'QYHRIW4L1Y5WF2MAPABDG5WNS4CVTPBPM5GJ35W5R02SLMB2' # your Foursquare ID
CLIENT_SECRET = 'SAKZYG1K2PN1Z0V1VXFZZYHQF33DAZBNOTALAHYY0UWPYSL0' # your Foursquare Secret
ACCESS_TOKEN = "CKH2T0S2LU3BPVWXVRZPKT45ATYZPC0UPXJS4V2MNDYLZNKI" # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QYHRIW4L1Y5WF2MAPABDG5WNS4CVTPBPM5GJ35W5R02SLMB2
# CLIENT_SECRET:SAKZYG1K2PN1Z0V1VXFZZYHQF33DAZBNOTALAHYY0UWPYSL0

# %%
address = '102 North End Ave, New York, NY'
address ='10 Hollywood Rd, Central'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 22.28122525 114.15404129440384
# Italian .... OK!
# 'https://api.foursquare.com/v2/venues/search?client_id=QYHRIW4L1Y5WF2MAPABDG5WNS4CVTPBPM5GJ35W5R02SLMB2&client_secret=SAKZYG1K2PN1Z0V1VXFZZYHQF33DAZBNOTALAHYY0UWPYSL0&ll=22.28122525,114.15404129440384&oauth_token=CKH2T0S2LU3BPVWXVRZPKT45ATYZPC0UPXJS4V2MNDYLZNKI&v=20180604&query=Italian&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60443ff44c0a8a5858471228'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '50b85b0eb0ed12b543c027b1',
#     'name': 'The Italian Chamber of Commerce in Hong Kong and Macao',
#     'location': {'address': "19/F, 168 Queen's Rd C",
#      'lat': 22.28560200136469,
#      'lng': 114.15402173995972,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.28560200136469,
#        'lng': 114.15402173995972}],
#      'distance': 487,
#      'cc': 'HK',
#      'city': '中環',
#      'state': '中西區',
#      'country': '香港',
#      'formattedAddress': ["19/F, 168 Queen's Rd C", '中西區', '香港']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '44972179'},
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '5f4496c87095a6746fd5d619',
#     'name': 'Aria Italian',
#     'location': {'address': "24/F, California Tower, 30-32 D'Aguilar Street, Central",
#      'lat': 22.2812,
#      'lng': 114.155436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.2812,
#        'lng': 114.155436}],
#      'distance': 143,
#      'cc': 'HK',
#      'neighborhood': 'Central and Western District',
#      'city': '中環',
#      'state': '中西區',
#      'country': '香港',
#      'formattedAddress': ["24/F, California Tower, 30-32 D'Aguilar Street, Central",
#       '中西區',
#       '香港']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '5c09185b7d849700398c61b9',
#     'name': 'Frank’s Italian American',
#     'location': {'address': '79 Wyndham Street',
#      'lat': 22.28184716404598,
#      'lng': 114.15458766520854,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.28184716404598,
#        'lng': 114.15458766520854}],
#      'distance': 89,
#      'cc': 'HK',
#      'city': '中環',
#      'state': '中西區',
#      'country': '香港',
#      'formattedAddress': ['79 Wyndham Street', '中西區', '香港']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '5faa1dbfecbec7730dfcad78',
#     'name': 'The Italian Club',
#     'location': {'address': '32 Elgin Street',
#      'lat': 22.281614,
#      'lng': 114.15255,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.281614,
#        'lng': 114.15255}],
#      'distance': 159,
#      'cc': 'HK',
#      'state': 'Hong Kong Island',
#      'country': '香港',
#      'formattedAddress': ['32 Elgin Street', 'Hong Kong Island', '香港']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '4ce283f600166ea874094788',
#     'name': 'Il Maestro Italian Restaurant',
#     'location': {'address': '75-77 Wyndham Street',
#      'lat': 22.282104,
#      'lng': 114.154999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.282104,
#        'lng': 114.154999}],
#      'distance': 138,
#      'cc': 'HK',
#      'city': '香港',
#      'country': '香港',
#      'formattedAddress': ['75-77 Wyndham Street', '香港']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '5afa7c18b23dfa002c198a5d',
#     'name': 'the italian club',
#     'location': {'address': '1-5 Elgin Street',
#      'crossStreet': 'Elgin & Peel Street',
#      'lat': 22.283029,
#      'lng': 114.152502,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.283029,
#        'lng': 114.152502}],
#      'distance': 255,
#      'cc': 'HK',
#      'city': '中環',
#      'state': '中西區',
#      'country': '香港',
#      'formattedAddress': ['1-5 Elgin Street (Elgin & Peel Street)',
#       '中西區',
#       '香港']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '5f64284cafe97a7c782894e3',
#     'name': 'Italian Tomato',
#     'location': {'lat': 22.283466,
#      'lng': 114.156079,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.283466,
#        'lng': 114.156079}],
#      'distance': 325,
#      'cc': 'HK',
#      'city': '中環',
#      'state': '中西區',
#      'country': '香港',
#      'formattedAddress': ['中西區', '香港']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '5905c5d2cad1b6166c7b87db',
#     'name': 'Oyster Station Italian Restaurant',
#     'location': {'address': '6/F Grand Progress Building',
#      'crossStreet': '15-16 Lan Kwai Fong, Central',
#      'lat': 22.280549,
#      'lng': 114.155388,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.280549,
#        'lng': 114.155388}],
#      'distance': 157,
#      'cc': 'HK',
#      'city': '香港',
#      'country': '香港',
#      'formattedAddress': ['6/F Grand Progress Building (15-16 Lan Kwai Fong, Central)',
#       '香港']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '4b1b8733f964a520dcfb23e3',
#     'name': 'Bistecca Italian Steak House',
#     'location': {'address': '2/F, Grand Progress Bldg, 15 Lan Kwai Fong',
#      'lat': 22.28052832085751,
#      'lng': 114.15532500671846,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.28052832085751,
#        'lng': 114.15532500671846}],
#      'distance': 153,
#      'cc': 'HK',
#      'city': '中環',
#      'state': '中西區',
#      'country': '香港',
#      'formattedAddress': ['2/F, Grand Progress Bldg, 15 Lan Kwai Fong',
#       '中西區',
#       '香港']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '570cc5e1cd10fded68a4addd',
#     'name': 'ilBelapaesse Italian Deli',
#     'location': {'address': "299 Queen's Rd. C.",
#      'lat': 22.284717,
#      'lng': 114.150561,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.284717,
#        'lng': 114.150561}],
#      'distance': 528,
#      'cc': 'HK',
#      'city': '中環',
#      'state': '中西區',
#      'country': '香港',
#      'formattedAddress': ["299 Queen's Rd. C.", '中西區', '香港']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '4bc52ce3ccbcef3bc745e6d2',
#     'name': 'Il Bel Paese',
#     'location': {'address': 'Shop B, G/F, 85 Caine Rd',
#      'lat': 22.28166507425702,
#      'lng': 114.15159210666118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.28166507425702,
#        'lng': 114.15159210666118}],
#      'distance': 256,
#      'cc': 'HK',
#      'city': 'Mid-levels',
#      'country': '香港',
#      'formattedAddress': ['Shop B, G/F, 85 Caine Rd', '香港']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '4b45f746f964a520111326e3',
#     'name': '8½ Otto e Mezzo Bombana',
#     'location': {'address': 'Unit 202, 2/F, Alexandra House, 18 Chater Rd',
#      'lat': 22.28172617346849,
#      'lng': 114.15876650396412,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.28172617346849,
#        'lng': 114.15876650396412}],
#      'distance': 489,
#      'cc': 'HK',
#      'city': '中環',
#      'state': '中西區',
#      'country': '香港',
#      'formattedAddress': ['Unit 202, 2/F, Alexandra House, 18 Chater Rd',
#       '中西區',
#       '香港']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False},
#    {'id': '5422509d498e33c1b4bedc7d',
#     'name': 'Gradini Ristorante E Bar Italiano',
#     'location': {'address': "Lobby, The Pottinger Hong Kong, 74 Queen's Rd C",
#      'crossStreet': '21 Stanley St',
#      'lat': 22.28310108334569,
#      'lng': 114.15543511554463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.28310108334569,
#        'lng': 114.15543511554463}],
#      'distance': 253,
#      'cc': 'HK',
#      'city': '香港',
#      'country': '香港',
#      'formattedAddress': ["Lobby, The Pottinger Hong Kong, 74 Queen's Rd C (21 Stanley St)",
#       '香港']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615085556',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id  \
# 0  50b85b0eb0ed12b543c027b1
# 1  5f4496c87095a6746fd5d619
# 2  5c09185b7d849700398c61b9
# 3  5faa1dbfecbec7730dfcad78
# 4  4ce283f600166ea874094788
#
#                                                 name  \
# 0  The Italian Chamber of Commerce in Hong Kong a...
# 1                                       Aria Italian
# 2                           Frank’s Italian American
# 3                                   The Italian Club
# 4                      Il Maestro Italian Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '50328a8e91d4c4b30a586d6c', 'name': 'N...  v-1615085556    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
#
#                                     location.address  location.lat  \
# 0                             19/F, 168 Queen's Rd C     22.285602
# 1  24/F, California Tower, 30-32 D'Aguilar Street...     22.281200
# 2                                  79 Wyndham Street     22.281847
# 3                                    32 Elgin Street     22.281614
# 4                               75-77 Wyndham Street     22.282104
#
#    location.lng                            location.labeledLatLngs  \
# 0    114.154022  [{'label': 'display', 'lat': 22.28560200136469...
# 1    114.155436  [{'label': 'display', 'lat': 22.2812, 'lng': 1...
# 2    114.154588  [{'label': 'display', 'lat': 22.28184716404598...
# 3    114.152550  [{'label': 'display', 'lat': 22.281614, 'lng':...
# 4    114.154999  [{'label': 'display', 'lat': 22.282104, 'lng':...
#
#    location.distance location.cc location.city    location.state  \
# 0                487          HK            中環               中西區
# 1                143          HK            中環               中西區
# 2                 89          HK            中環               中西區
# 3                159          HK           NaN  Hong Kong Island
# 4                138          HK            香港               NaN
#
#   location.country                          location.formattedAddress  \
# 0               香港                  [19/F, 168 Queen's Rd C, 中西區, 香港]
# 1               香港  [24/F, California Tower, 30-32 D'Aguilar Stree...
# 2               香港                       [79 Wyndham Street, 中西區, 香港]
# 3               香港            [32 Elgin Street, Hong Kong Island, 香港]
# 4               香港                         [75-77 Wyndham Street, 香港]
#
#   venuePage.id         location.neighborhood location.crossStreet
# 0     44972179                           NaN                  NaN
# 1          NaN  Central and Western District                  NaN
# 2          NaN                           NaN                  NaN
# 3          NaN                           NaN                  NaN
# 4          NaN                           NaN                  NaN

# %%
dataframe
# Out:
#                           id  \
# 0   50b85b0eb0ed12b543c027b1
# 1   5f4496c87095a6746fd5d619
# 2   5c09185b7d849700398c61b9
# 3   5faa1dbfecbec7730dfcad78
# 4   4ce283f600166ea874094788
# 5   5afa7c18b23dfa002c198a5d
# 6   5f64284cafe97a7c782894e3
# 7   5905c5d2cad1b6166c7b87db
# 8   4b1b8733f964a520dcfb23e3
# 9   570cc5e1cd10fded68a4addd
# 10  4bc52ce3ccbcef3bc745e6d2
# 11  4b45f746f964a520111326e3
# 12  5422509d498e33c1b4bedc7d
#
#                                                  name  \
# 0   The Italian Chamber of Commerce in Hong Kong a...
# 1                                        Aria Italian
# 2                            Frank’s Italian American
# 3                                    The Italian Club
# 4                       Il Maestro Italian Restaurant
# 5                                    the italian club
# 6                                      Italian Tomato
# 7                   Oyster Station Italian Restaurant
# 8                        Bistecca Italian Steak House
# 9                           ilBelapaesse Italian Deli
# 10                                       Il Bel Paese
# 11                            8½ Otto e Mezzo Bombana
# 12                  Gradini Ristorante E Bar Italiano
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '50328a8e91d4c4b30a586d6c', 'name': 'N...  v-1615085556    False
# 1   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
# 2   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
# 3   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
# 4   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
# 5   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
# 6   [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...  v-1615085556    False
# 7   [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...  v-1615085556    False
# 8   [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  v-1615085556    False
# 9   [{'id': '4bf58dd8d48988d146941735', 'name': 'D...  v-1615085556    False
# 10  [{'id': '4bf58dd8d48988d146941735', 'name': 'D...  v-1615085556    False
# 11  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
# 12  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615085556    False
#
#                                      location.address  location.lat  \
# 0                              19/F, 168 Queen's Rd C     22.285602
# 1   24/F, California Tower, 30-32 D'Aguilar Street...     22.281200
# 2                                   79 Wyndham Street     22.281847
# 3                                     32 Elgin Street     22.281614
# 4                                75-77 Wyndham Street     22.282104
# 5                                    1-5 Elgin Street     22.283029
# 6                                                 NaN     22.283466
# 7                         6/F Grand Progress Building     22.280549
# 8          2/F, Grand Progress Bldg, 15 Lan Kwai Fong     22.280528
# 9                                  299 Queen's Rd. C.     22.284717
# 10                           Shop B, G/F, 85 Caine Rd     22.281665
# 11       Unit 202, 2/F, Alexandra House, 18 Chater Rd     22.281726
# 12    Lobby, The Pottinger Hong Kong, 74 Queen's Rd C     22.283101
#
#     location.lng                            location.labeledLatLngs  \
# 0     114.154022  [{'label': 'display', 'lat': 22.28560200136469...
# 1     114.155436  [{'label': 'display', 'lat': 22.2812, 'lng': 1...
# 2     114.154588  [{'label': 'display', 'lat': 22.28184716404598...
# 3     114.152550  [{'label': 'display', 'lat': 22.281614, 'lng':...
# 4     114.154999  [{'label': 'display', 'lat': 22.282104, 'lng':...
# 5     114.152502  [{'label': 'display', 'lat': 22.283029, 'lng':...
# 6     114.156079  [{'label': 'display', 'lat': 22.283466, 'lng':...
# 7     114.155388  [{'label': 'display', 'lat': 22.280549, 'lng':...
# 8     114.155325  [{'label': 'display', 'lat': 22.28052832085751...
# 9     114.150561  [{'label': 'display', 'lat': 22.284717, 'lng':...
# 10    114.151592  [{'label': 'display', 'lat': 22.28166507425702...
# 11    114.158767  [{'label': 'display', 'lat': 22.28172617346849...
# 12    114.155435  [{'label': 'display', 'lat': 22.28310108334569...
#
#     location.distance location.cc location.city    location.state  \
# 0                 487          HK            中環               中西區
# 1                 143          HK            中環               中西區
# 2                  89          HK            中環               中西區
# 3                 159          HK           NaN  Hong Kong Island
# 4                 138          HK            香港               NaN
# 5                 255          HK            中環               中西區
# 6                 325          HK            中環               中西區
# 7                 157          HK            香港               NaN
# 8                 153          HK            中環               中西區
# 9                 528          HK            中環               中西區
# 10                256          HK    Mid-levels               NaN
# 11                489          HK            中環               中西區
# 12                253          HK            香港               NaN
#
#    location.country                          location.formattedAddress  \
# 0                香港                  [19/F, 168 Queen's Rd C, 中西區, 香港]
# 1                香港  [24/F, California Tower, 30-32 D'Aguilar Stree...
# 2                香港                       [79 Wyndham Street, 中西區, 香港]
# 3                香港            [32 Elgin Street, Hong Kong Island, 香港]
# 4                香港                         [75-77 Wyndham Street, 香港]
# 5                香港  [1-5 Elgin Street (Elgin & Peel Street), 中西區, 香港]
# 6                香港                                          [中西區, 香港]
# 7                香港  [6/F Grand Progress Building (15-16 Lan Kwai F...
# 8                香港  [2/F, Grand Progress Bldg, 15 Lan Kwai Fong, 中...
# 9                香港                      [299 Queen's Rd. C., 中西區, 香港]
# 10               香港                     [Shop B, G/F, 85 Caine Rd, 香港]
# 11               香港  [Unit 202, 2/F, Alexandra House, 18 Chater Rd,...
# 12               香港  [Lobby, The Pottinger Hong Kong, 74 Queen's Rd...
#
#    venuePage.id         location.neighborhood          location.crossStreet
# 0      44972179                           NaN                           NaN
# 1           NaN  Central and Western District                           NaN
# 2           NaN                           NaN                           NaN
# 3           NaN                           NaN                           NaN
# 4           NaN                           NaN                           NaN
# 5           NaN                           NaN           Elgin & Peel Street
# 6           NaN                           NaN                           NaN
# 7           NaN                           NaN  15-16 Lan Kwai Fong, Central
# 8           NaN                           NaN                           NaN
# 9           NaN                           NaN                           NaN
# 10          NaN                           NaN                           NaN
# 11          NaN                           NaN                           NaN
# 12          NaN                           NaN                 21 Stanley St

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name          categories  \
# 0   The Italian Chamber of Commerce in Hong Kong a...          Non-Profit
# 1                                        Aria Italian  Italian Restaurant
# 2                            Frank’s Italian American  Italian Restaurant
# 3                                    The Italian Club  Italian Restaurant
# 4                       Il Maestro Italian Restaurant  Italian Restaurant
# 5                                    the italian club  Italian Restaurant
# 6                                      Italian Tomato        Dessert Shop
# 7                   Oyster Station Italian Restaurant  Seafood Restaurant
# 8                        Bistecca Italian Steak House          Steakhouse
# 9                           ilBelapaesse Italian Deli       Deli / Bodega
# 10                                       Il Bel Paese       Deli / Bodega
# 11                            8½ Otto e Mezzo Bombana  Italian Restaurant
# 12                  Gradini Ristorante E Bar Italiano  Italian Restaurant
#
#                                               address        lat         lng  \
# 0                              19/F, 168 Queen's Rd C  22.285602  114.154022
# 1   24/F, California Tower, 30-32 D'Aguilar Street...  22.281200  114.155436
# 2                                   79 Wyndham Street  22.281847  114.154588
# 3                                     32 Elgin Street  22.281614  114.152550
# 4                                75-77 Wyndham Street  22.282104  114.154999
# 5                                    1-5 Elgin Street  22.283029  114.152502
# 6                                                 NaN  22.283466  114.156079
# 7                         6/F Grand Progress Building  22.280549  114.155388
# 8          2/F, Grand Progress Bldg, 15 Lan Kwai Fong  22.280528  114.155325
# 9                                  299 Queen's Rd. C.  22.284717  114.150561
# 10                           Shop B, G/F, 85 Caine Rd  22.281665  114.151592
# 11       Unit 202, 2/F, Alexandra House, 18 Chater Rd  22.281726  114.158767
# 12    Lobby, The Pottinger Hong Kong, 74 Queen's Rd C  22.283101  114.155435
#
#                                        labeledLatLngs  distance  cc  \
# 0   [{'label': 'display', 'lat': 22.28560200136469...       487  HK
# 1   [{'label': 'display', 'lat': 22.2812, 'lng': 1...       143  HK
# 2   [{'label': 'display', 'lat': 22.28184716404598...        89  HK
# 3   [{'label': 'display', 'lat': 22.281614, 'lng':...       159  HK
# 4   [{'label': 'display', 'lat': 22.282104, 'lng':...       138  HK
# 5   [{'label': 'display', 'lat': 22.283029, 'lng':...       255  HK
# 6   [{'label': 'display', 'lat': 22.283466, 'lng':...       325  HK
# 7   [{'label': 'display', 'lat': 22.280549, 'lng':...       157  HK
# 8   [{'label': 'display', 'lat': 22.28052832085751...       153  HK
# 9   [{'label': 'display', 'lat': 22.284717, 'lng':...       528  HK
# 10  [{'label': 'display', 'lat': 22.28166507425702...       256  HK
# 11  [{'label': 'display', 'lat': 22.28172617346849...       489  HK
# 12  [{'label': 'display', 'lat': 22.28310108334569...       253  HK
#
#           city             state country  \
# 0           中環               中西區      香港
# 1           中環               中西區      香港
# 2           中環               中西區      香港
# 3          NaN  Hong Kong Island      香港
# 4           香港               NaN      香港
# 5           中環               中西區      香港
# 6           中環               中西區      香港
# 7           香港               NaN      香港
# 8           中環               中西區      香港
# 9           中環               中西區      香港
# 10  Mid-levels               NaN      香港
# 11          中環               中西區      香港
# 12          香港               NaN      香港
#
#                                      formattedAddress  \
# 0                   [19/F, 168 Queen's Rd C, 中西區, 香港]
# 1   [24/F, California Tower, 30-32 D'Aguilar Stree...
# 2                        [79 Wyndham Street, 中西區, 香港]
# 3             [32 Elgin Street, Hong Kong Island, 香港]
# 4                          [75-77 Wyndham Street, 香港]
# 5   [1-5 Elgin Street (Elgin & Peel Street), 中西區, 香港]
# 6                                           [中西區, 香港]
# 7   [6/F Grand Progress Building (15-16 Lan Kwai F...
# 8   [2/F, Grand Progress Bldg, 15 Lan Kwai Fong, 中...
# 9                       [299 Queen's Rd. C., 中西區, 香港]
# 10                     [Shop B, G/F, 85 Caine Rd, 香港]
# 11  [Unit 202, 2/F, Alexandra House, 18 Chater Rd,...
# 12  [Lobby, The Pottinger Hong Kong, 74 Queen's Rd...
#
#                     neighborhood                   crossStreet  \
# 0                            NaN                           NaN
# 1   Central and Western District                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# 5                            NaN           Elgin & Peel Street
# 6                            NaN                           NaN
# 7                            NaN  15-16 Lan Kwai Fong, Central
# 8                            NaN                           NaN
# 9                            NaN                           NaN
# 10                           NaN                           NaN
# 11                           NaN                           NaN
# 12                           NaN                 21 Stanley St
#
#                           id
# 0   50b85b0eb0ed12b543c027b1
# 1   5f4496c87095a6746fd5d619
# 2   5c09185b7d849700398c61b9
# 3   5faa1dbfecbec7730dfcad78
# 4   4ce283f600166ea874094788
# 5   5afa7c18b23dfa002c198a5d
# 6   5f64284cafe97a7c782894e3
# 7   5905c5d2cad1b6166c7b87db
# 8   4b1b8733f964a520dcfb23e3
# 9   570cc5e1cd10fded68a4addd
# 10  4bc52ce3ccbcef3bc745e6d2
# 11  4b45f746f964a520111326e3
# 12  5422509d498e33c1b4bedc7d

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_53e8ce103e6242c698bea12154a6c8ad%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_53e8ce103e6242c698bea12154a6c8ad%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_53e8ce103e6242c698bea12154a6c8ad%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_53e8ce103e6242c698bea12154a6c8ad%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B22.28122525%2C114.15404129440384%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20 ...
